# %% [markdown]
# # ISTAT

# %%
from pandasdmx import Request

# %%
istat = Request('ISTAT')

# %%
# download a list of dataflow definitions for all dataflows provided

# %%
flow_response = istat.dataflow()

# %%
dir(flow_response.msg)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_attr_codes',
#  '_attr_ids',
#  '_constrainables',
#  '_constrained_codes',
#  '_content_types',
#  '_dim_codes',
#  '_dim_ids',
#  '_elem',
#  '_in_codes',
#  '_in_constraints',
#  '_reader',
#  'dataflow',
#  'header']

# %%
flow_response.url
# Out:
# 'http://sdmx.istat.it/SDMXWS/rest/dataflow/latest/'

# %%
flow_response.dataflow
# Out:
# {'101_148': DataflowDefinition | 101_148 | Economic results of farms,
#  '101_22': DataflowDefinition | 101_22 | Plant protection products,
#  '101_959': DataflowDefinition | 101_959 | Milk and dairy products,
#  '101_961': DataflowDefinition | 101_961 | Livestock,
#  '101_962': DataflowDefinition | 101_962 | Livestock import export,
#  '101_965': DataflowDefinition | 101_965 | Agritourism,
#  '105_123': DataflowDefinition | 105_123 | Total area and production,
#  '105_127': DataflowDefinition | 105_127 | Number of farms and areas,
#  '106_120': DataflowDefinition | 106_120 | Number of farms and heads,
#  '111_111': DataflowDefinition | 111_111 | Building permits  indicators,
#  '111_263': DataflowDefinition | 111_263 | Business confidence in the manufacturing sector,
#  '111_40': DataflowDefinition | 111_40 | Business confidence in the construction sector,
#  '111_476': DataflowDefinition | 111_476 | Building permits indicators,
# ...

# %%
flow_response.http_headers
# Out:
# {'Date': 'Mon, 03 Dec 2018 14:29:49 GMT', 'Cache-Control': 'private', 'X-AspNet-Version': '4.0.30319', 'Transfer-Encoding': 'chunked', 'Server': 'Microsoft-IIS/7.5', 'X-Cache-Lookup': 'MISS from box1-t19:3128', 'Via': '1.1 sdmx.istat.it', 'X-Powered-By': 'ASP.NET', 'Content-Type': 'application/vnd.sdmx.structure+xml; version=2.1', 'X-Cache': 'MISS from box1-t19', 'Connection': 'keep-alive', 'Set-Cookie': 'dtCookie=A2596FF70C63004AE17AF678D31AE05E|c2RteHwx; Path=/; Domain=.istat.it; Secure'}

# %%
flow_response.write().dataflow.head()
# Out:
#                                name
# dataflow
# 101_148   Economic results of farms
# 101_22    Plant protection products
# 101_959     Milk and dairy products
# 101_961                   Livestock
# 101_962     Livestock import export

# %%
flow = istat.dataflow('9_951')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-30-9830d6ed378a> in <module>
# ----> 1 flow = istat.dataflow('9_951')
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandasdmx/api.py in get(self, resource_type, resource_id, agency, version, key, params, headers, fromfile, tofile, url, get_footer_url, memcache, writer, dsd, series_keys)
#     359             'Requesting resource from URL/file %s', (base_url or fromfile))
#     360         source, url, resp_headers, status_code = self.client.get(
# --> 361             base_url, params=params, headers=headers, fromfile=fromfile)
#     362         if source is None:
#     363             raise SDMXException('Server error:', status_code, url)
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandasdmx/remote.py in get(self, url, fromfile, params, headers)
#      96         else:
# ...
