# %% [markdown]
# # ISTAT
#
# WEB SERVICE SDMX PER L'ACCESSO AI DATI DI I.STAT
#
# https://www.istat.it/it/metodi-e-strumenti/web-service
#
# Aggiornamento dei dataset:
#
# https://www.istat.it/it/metodi-e-strumenti/web-service/aggiornamenti-dataset
#
# TOOL ED ESEMPI DI SVILUPPO DI APPLICAZIONI:
#
# https://www.istat.it/it/metodi-e-strumenti/web-service/tool-e-applicazioni
#
# ISTAT Registry:
# http://sdmx.istat.it/sdmxMetaRepository/codelistItemDetails.aspx?ACTION=UPDATE&ID=CL_AGGREG_INCIDVEIC&AGENCY=IT1&VERSION=1.0&ISFINAL=True#codes
#
# **ENDPOINT**
#
# Banca dati principale: http://sdmx.istat.it/SDMXWS/
#
# Censimento dell'agricoltura 2010: http://sdmx.istat.it/WS_CENSAGR/
#
# Censimento della popolazione e delle abitazioni 2011: http://sdmx.istat.it/WS_CENSPOP/
#
# Censimento dell'industria e dei servizi 2011: http://sdmx.istat.it/WS_CIS/
#
#
#
# **FAQ:**
#
# il servizio è libero e gratuito
#
# https://www.istat.it/it/metodi-e-strumenti/web-service/faq

# %%
from pandasdmx import Request

# %%
istat = Request('ISTAT')

# %%
istat.agency
# Out:
# 'ISTAT'

# %%
flow_response = istat.dataflow()

# %%
# download a list of dataflow definitions for all dataflows provided

# %%
flow_response.url
# Out:
# 'http://sdmx.istat.it/SDMXWS/rest/dataflow/latest/'

# %%
dir(flow_response.msg)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_attr_codes',
#  '_attr_ids',
#  '_constrainables',
#  '_constrained_codes',
#  '_content_types',
#  '_dim_codes',
#  '_dim_ids',
#  '_elem',
#  '_in_codes',
#  '_in_constraints',
#  '_reader',
#  'dataflow',
#  'header']

# %%
flow_response.write().dataflow
# Out:
#                                                        name
# dataflow
# 101_148                           Economic results of farms
# 101_22                            Plant protection products
# 101_959                             Milk and dairy products
# 101_961                                           Livestock
# 101_962                             Livestock import export
# 101_965                                         Agritourism
# 105_123                           Total area and production
# 105_127                           Number of farms and areas
# 106_120                           Number of farms and heads
# 111_111                        Building permits  indicators
# 111_263     Business confidence in the manufacturing sector
# 111_40       Business confidence in the construction sector
# 111_476                         Building permits indicators
# 114_191   Industrial new orders and turnover index - mon...
# ...

# %%
flow_response.http_headers
# Out:
# {'Keep-Alive': 'timeout=10, max=999', 'Server': 'Microsoft-IIS/7.5', 'Date': 'Mon, 17 Dec 2018 11:19:09 GMT', 'Connection': 'Keep-Alive', 'Cache-Control': 'private', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'dtCookie=A3A05A45A3B4FF24D1319AC2EEBBFAB8|c2RteHwx; Path=/; Domain=.istat.it; Secure', 'Transfer-Encoding': 'chunked', 'Via': '1.1 sdmx.istat.it', 'Content-Type': 'application/vnd.sdmx.structure+xml; version=2.1', 'X-AspNet-Version': '4.0.30319'}

# %%
flow_response.write().dataflow.head()
# Out:
#                                name
# dataflow
# 101_148   Economic results of farms
# 101_22    Plant protection products
# 101_959     Milk and dairy products
# 101_961                   Livestock
# 101_962     Livestock import export

# %%
flow = istat.dataflow('101_962')

# %%
test = istat.dataflow.101_962.structure()
# Out:
#   File "<ipython-input-30-0eb3e45280b1>", line 1
#     test = istat.dataflow.101_962.structure()
#                             ^
# SyntaxError: invalid syntax

# %%
istat.dataflow?
